# %%
A = True
B = True
C = False
# %whos

# %%
print (A and B)
print (A and C)
print (C and A)

# %%
D = A or C

# %%
print(D)

# %%
not(A)
not(B)
not(C)
not(D)
t = not(D)
print(t)

# %%
not ((A and B) or (C or D))

# %% [markdown]
# # Comparisons

# %%
print(2>3)

# %%
c = 2<3
print(type(c))
print(c)

# %%
3 == 4
d = 3 == 4
print(d)
3 == 3.0

# %%
x = 4
y = 9
z = 8.3
r = -3
(x<y) and (z<y) or (r==x)

# %%
print((not(2!=3) and True) or (False and True))
