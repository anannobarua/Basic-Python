# %% [markdown]
# # round()

# %%
round(4.6)

# %%
print(round(4.5667,3))

# %%
print(round(2.1145,2))

# %% [markdown]
# # divmod(x,y)

# %%
divmod(22,10)

# %%
G = divmod(33,9)
type(G)

# %%
print(G)
G[0]

# %% [markdown]
# # IsInstance()

# %%
# x=2, y=int then Print True, Cause its print the x is which type
isinstance(3, int)

# %%
isinstance(3.4, int)

# %%
isinstance(3.4,(float,int))

# %%
isinstance(2+3j,(int,float,str,complex))

# %% [markdown]
# # Pow(x,y,z)

# %%
# x raise to the power y and remainder by z

pow(2,4)

# %%
pow(2,4,7)

# %% [markdown]
# # input()

# %%
x= input ("Enter Anyword:")
type(x)
x = int(x)
type(x)
print(x-34)

# %%
a = float(input("Enter a real number: "))
type(a)

# %%
b = float(input("Enter :"))
type(b)
