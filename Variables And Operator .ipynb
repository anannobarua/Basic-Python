# %% [markdown]
# #Variables Example

# %%
x=3

# %%
# %whos

# %%
print(type(x))

# %%
y=5.3

# %%
# %whos

# %%
print(type(y))

# %%
a,b,c,d,e,f=3,3.3,4,5,-4,88

# %%
# %whos

# %%
 abcd= 98

# %%
# %whos

# %%
del abcd

# %%
#print(abcd) [Error Call]

# %% [markdown]
# **Complex Variable**

# %%
c = 2+7j

# %%
print(type(c))

# %%
d= "I am Ananno"

# %%
print(type(d))

# %% [markdown]
# # Operator Example

# %%
# %whos

# %%
sumOfaAndb = a+b

# %%
print(sumOfaAndb)

# %%
type(sumOfaAndb)

# %%
type(a+c)

# %%
v = ((a+b)**10)/2

# %%
print(v)

# %%
s1 = "Hello"
s2 = "World"
s = s1 + s2
print(s)

# %%
10/3

# %%
10//3

# %%
_
